# %% [markdown]
# ### 2.1. Creación de la clase **Libro**.
# ###  Explicación del ejercicio:
#
# En este ejercicio, definiremos una clase llamada `Libro` que representa un libro en nuestro futuro e-commerce.
#
#  ### Código a seguir:
# 1. **Definición de la clase Libro:**
#    - Creamos una clase llamada `Libro` con un constructor `__init__` para inicializar los atributos `titulo`, `autor` y `precio`.
#
# 2. **Creación de la instancia de la clase Libro:**
#    - Creamos una instancia de la clase `Libro` con los atributos proporcionados: título ("La Comunidad del Anillo"), autor ("J.R.R.Tolkien") y precio (29.99).
#
# 3. **Impresión del tipo de objeto:**
#    - Utilizamos la función `type()` para imprimir el tipo de objeto de la variable `libro1`.
#
# ### 2.2. Métodos adicionales para la clase **Libro**.
# ###  Explicación del ejercicio:
#
# En este ejercicio, ampliaremos la clase `Libro` con métodos adicionales para establecer la cantidad de libros disponibles y obtener información detallada del libro.
#
#  ### Código a seguir:
# 1. **Definición del método para establecer la cantidad de libros disponibles:**
#    - Definimos un método llamado `establecer_cantidad()` dentro de la clase `Libro` para permitir al usuario establecer la cantidad de libros disponibles.
#    - Este método solicitará al usuario que ingrese la cantidad de libros y la asignará al atributo `cantidad` del libro.
#
# 2. **Definición del método para obtener información detallada del libro:establecer_cantidad()**
#    - Definimos un método llamado `info_libro()` dentro de la clase `Libro` para obtener información detallada del libro.
#    - Este método devolverá una cadena con el título, autor, precio y cantidad disponible del libro.
#
# 3. **Instanciación y llamada a métodos:**
#    - Creamos una nueva instancia de la clase Libro.
#    - Llamamos al método `establecer_cantidad` para establecer la cantidad de libros disponibles.
#    - Llamamos al método `info_libro` para obtener información sobre el libro.
# ---

# %%
from datetime import datetime,timedelta

class Libro:
    def __init__(self,título,autor,precio):
      """ Inicializa un libro con los atributos titulo autor precio
      Paraqmetros(título, autor y precio)"""
      self.título = título
      self.autor = autor
      self.precio = precio
      self.cantidad =0
  #Definimos métodos para la clase Libro:
    def establecer_cantidad(self):
         """ Fx para ingresar la cantidad de libros con las caracteristicas del mismo"""
         """" Ingresar un número positivo"""
         while True:
            try:
                cantidad = int(input(f'Ingrese la cantidad del libro con título {self.título}: ')) 
                if cantidad <0:
                    print(f"La cantidad no puede  ser negativa, por favor intentelo de nuevo")
                else :
                        # Asignamos la cantidad al atributo 'cantidad'
                    self.cantidad = cantidad #hemos introducido el atributo en la clase ibro
                    break
            except ValueError:
                print(f"Debe introdcir un numero")

             
    def info_libro(self) :
        info =""
        info += "Título:"+ self.título + "\n"
        info += "Autor:" + self.autor + "\n"
        info += "Precio:" + str(self.precio) + "\n"
        info += "Cantidad:" + str(self.cantidad) + "\n"
        return info
  
libro_1= Libro("La Comunidad del Anillo","J.R.R.Tolkien",29.99)
print(libro_1.info_libro())
libro_1.establecer_cantidad()
print(libro_1.info_libro())
# Out:
# Título:La Comunidad del Anillo
# Autor:J.R.R.Tolkien
# Precio:29.99
# Cantidad:0
#
# Título:La Comunidad del Anillo
# Autor:J.R.R.Tolkien
# Precio:29.99
# Cantidad:5

# %% [markdown]
# ### 2.3. Herencia en la clase **Libro**.
# ###  Explicación del ejercicio:
#
# En este ejercicio, introduciremos herencia en nuestra jerarquía de clases agregando dos subclases: `LibroFisico` y `AudioLibro`.
#
#  ### Código a seguir:
# 1. **Definición de la clase LibroFisico:**
#    - Creamos una clase llamada `LibroFisico` que representa un libro físico.
#    - Esta clase hereda de la clase base `Libro`.
#    - Definimos un constructor `__init__` que inicializa los atributos `titulo`, `autor`, `precio`, `categoria` y `peso`.
#
# 2. **Definición de la clase AudioLibro:**
#    - Creamos una clase llamada `AudioLibro` que representa un audiolibro.
#    - Esta clase también hereda de la clase base `Libro`.
#    - Definimos un constructor `__init__` que inicializa los atributos `titulo`, `autor`, `precio`, `categoria` y `duracion`.
#
# ### 2.4. Métodos adicionales para las clases **LibroFisico** y **AudioLibro**.
# ###  Explicación del ejercicio:
#
# En este ejercicio, agregaremos métodos adicionales a las clases `LibroFisico` y `AudioLibro` para mejorar su funcionalidad.
#
#  ### Código a seguir:
# 1. **Definición del método para calcular la fecha estimada de entrega en la clase LibroFisico:**
#    - Agregamos un método llamado `envio()` dentro de la clase `LibroFisico` para calcular la fecha estimada de entrega.
#    - Este método toma un parámetro opcional `dias_envio` que representa el número de días estimados para el envío. Pondremos 5 por defecto.
#    - Utiliza las clases `datetime` y `timedelta` del módulo `datetime` para realizar cálculos de fechas.
#    - Retorna la fecha estimada de entrega.
#
# 2. **Definición del método para convertir la duración del audiolibro en formato HH:MM:SS en la clase AudioLibro:**
#    - Agregamos un método llamado `obtener_duracion()` dentro de la clase `AudioLibro` para convertir la duración del audiolibro en formato HH:MM:SS.
#    - Este método calcula las horas, minutos y segundos a partir de la duración total en segundos y los concatena en un formato de hora.
#    - Retorna la duración en formato HH:MM:SS.
#
# ---
# ---

# %%
""" Hacemos las subclases  `LibroFisico` y  `AudioLibro """
class LibroFísico(Libro):
    def __init__(self, título, autor, precio,categoría, peso):
        super().__init__(título,autor,precio)
        self.caegoría= categoría
        self.peso= peso

    def envío(self,días_envío =5):# especificando el valor en dias de evio lo tomara por dfecto, si cambia lo indcaos cuando llamemos a la fx
        hoy =datetime.now() # esta fx now() de la libreria datetime coge la fecha de ahora( hemos impoprtado la libreria) 
        fecha_entrega = hoy + timedelta(days= días_envío)
        return fecha_entrega
    def info_libro(self):
        info_libro= super().info_libro()
        info_libro += "Categoría" + self.categoría +"\n"
        info_libro += "Peso" + str(self.peso )+"\n"
        info_libro += "Fecha_entrega" + str(self.enío().strftime("%Y-%m-%d")) +"\n"# llamo al metodo de envio para q me lo calcule y ademas con strftime formateo la fecha ho9y que viene con segundo para q solo aparezca el años mes y dia
        return info_libro

class AudioLibro(Libro):
    def __init__(self, título, autor, precio, categoría, duración):
        super().__init__(título, autor, precio)
        self.categoría = categoría
        self.duración = duración

    def obtener_duración(self):
        horas = str(self.duración// 3600)
        minutos = str((self.duración % 3600) // 60) # % estamos obteniendo el resto de 360 e las hras
        segundos = str(self.duracion % 60)
        duracion_formateada= horas + ":" + minutos + ":" + segundos
        return duracion_formateada
    
    def info_libro(self):
        info_libro= super().info_libro()
        info_libro += "Categoría" + self.categoría +"\n"
        info_libro += "Duración en segundos" + str(self.duración )+"\n"
        info_libro += "Duración" + self.obtener_duración() +"\n"# llamo al metodo de obtener duración formateada
        return info_libro
    ##parte 2

class ECommerce:
    def __init__(self):
        self.carrito = []
        self.inventario = {}
    def agrgar_al_inventario(self,producto):
        self.producto = Libr

# %% [markdown]
# ### 2.5. Polimorfismo en las clases **LibroFisico** y **AudioLibro**.
# ###  Explicación del ejercicio:
#
# En este ejercicio, implementaremos polimorfismo en las clases `LibroFisico` y `AudioLibro` al sobrescribir el método `info_libro()` para proporcionar información detallada específica de cada tipo de libro.
#
#  ### Código a seguir:
# 1. **Definición del método `info_libro()` en la clase LibroFisico:**
#    - Sobrescribimos el método `info_libro()` en la clase `LibroFisico` para incluir información adicional como la categoría del libro físico, el peso y la fecha estimada de entrega.
#    - Llamamos al método `info_libro()` de la clase padre para obtener la información básica del libro.
#    - Agregamos la categoría del libro físico, el peso y la fecha de entrega estimada a la cadena de información.
#    - Retornamos la cadena con la información del libro físico.
#
# 2. **Definición del método `info_libro()` en la clase AudioLibro:**
#    - Sobrescribimos el método `info_libro()` en la clase `AudioLibro` para incluir información adicional como la categoría del audiolibro, la duración en segundos y la duración en formato HH:MM:SS.
#    - Llamamos al método `info_libro()` de la clase padre para obtener la información básica del libro.
#    - Agregamos la categoría del audiolibro, la duración en segundos y la duración en formato HH:MM:SS a la cadena de información.
#    - Retornamos la cadena con la información del audiolibro.

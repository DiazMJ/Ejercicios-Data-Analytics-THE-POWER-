# %%
import psycopg2
import pandas as pd

# %pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.4.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.15.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# certifi                   2024.6.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# colorama                  0.4.6
# comm                      0.2.1
# contourpy                 1.2.0
# cycler                    0.12.1
# DateTime                  5.4
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.0.1
# fastjsonschema            2.20.0
# fonttools                 4.49.0
# fqdn                      1.5.1
# grpcio                    1.64.1
# ...

# %%
conn = psycopg2.connect(host = "localhost", 
                        database = "Sakila" ,
                        user = "postgres", 
                        password = "postgres")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 conn = psycopg2.connect(host = "localhost",
#       2                         database = "Sakila" ,
#       3                         user = "postgres",
#       4                         password = "postgres")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\psycopg2\__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf3 in position 85: invalid continuation byte
